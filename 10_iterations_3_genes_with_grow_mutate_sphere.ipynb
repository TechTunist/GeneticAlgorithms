# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob
import numpy as np

# %%
# 1st hyperparameter settings
sphere_pop100_mutrate0_1_mutrange0_5 = glob.glob('csv_results/10_iterations_3_genes_grow_mutate_added/sphere_experiment_pop100_mutrate0.1_mutrange0.5/*.csv')
csv_list = []

for csv_file in sphere_pop100_mutrate0_1_mutrange0_5:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop100_mutrate0_1_mutrange0_5_df = pd.concat(csv_list, ignore_index=True)

sphere_pop100_mutrate0_1_mutrange0_5_df.head(5)
# Out:
#    max_distance  min_distance  avg_distance  avg_speed  path_straightness
# 0      4.676862      1.374013      2.617018   0.109042           0.448354
# 1      5.761036      1.585342      2.707148   0.112798           0.467085
# 2      5.611806      1.657105      2.606401   0.108600           0.508153
# 3      5.611806      1.750594      2.362000   0.098417           0.522084
# 4      5.346063      1.683463      2.686693   0.111946           0.522839

# %%
# 2nd hyperparameter settings
sphere_pop100_mutrate0_2_mutrange0_5 = glob.glob('csv_results/10_iterations_3_genes_grow_mutate_added/sphere_experiment_pop100_mutrate0.2_mutrange0.5/*.csv')
csv_list = []

for csv_file in sphere_pop100_mutrate0_2_mutrange0_5:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop100_mutrate0_2_mutrange0_5_df = pd.concat(csv_list, ignore_index=True)

sphere_pop100_mutrate0_2_mutrange0_5_df.head(5)
# Out:
#    max_distance  min_distance  avg_distance  avg_speed  path_straightness
# 0     11.119188      1.138342      2.618121   0.109088           0.444171
# 1      6.696910      1.626159      2.571596   0.107150           0.488978
# 2      6.089869      1.629775      2.636812   0.109867           0.500661
# 3      7.448963      1.584092      2.722806   0.113450           0.483764
# 4      5.194213      1.490793      2.707952   0.112831           0.497218

# %%
# 3rd hyperparameter settings
sphere_pop200_mutrate0_1_mutrange0_5 = glob.glob('csv_results/10_iterations_3_genes_grow_mutate_added/sphere_experiment_pop200_mutrate0.1_mutrange0.5/*.csv')
csv_list = []

for csv_file in sphere_pop200_mutrate0_1_mutrange0_5:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop200_mutrate0_1_mutrange0_5_df = pd.concat(csv_list, ignore_index=True)

sphere_pop200_mutrate0_1_mutrange0_5_df.head(5)
# Out:
#    max_distance  min_distance  avg_distance  avg_speed  path_straightness
# 0      6.969668      1.438776      2.580039   0.107502           0.433727
# 1      9.491094      1.488785      2.849892   0.118745           0.435420
# 2     10.370550      1.687235      3.165019   0.131876           0.458829
# 3      9.311243      0.967784      3.350105   0.139588           0.464420
# 4     10.718766      1.554620      3.762889   0.156787           0.550479

# %%
# 4th hyperparameter settings
sphere_pop200_mutrate0_5_mutrange0_5 = glob.glob('csv_results/10_iterations_3_genes_grow_mutate_added/sphere_experiment_pop200_mutrate0.5_mutrange0.5/*.csv')
csv_list = []

for csv_file in sphere_pop200_mutrate0_5_mutrange0_5:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop200_mutrate0_5_mutrange0_5_df = pd.concat(csv_list, ignore_index=True)

sphere_pop200_mutrate0_5_mutrange0_5_df.head(5)
# Out:
#    max_distance  min_distance  avg_distance  avg_speed  path_straightness
# 0      6.788473      1.312769      2.645598   0.110233           0.454662
# 1      7.821891      1.638933      3.052042   0.127168           0.488618
# 2      6.654731      1.567908      2.883953   0.120165           0.476405
# 3      6.975773      1.582412      2.774990   0.115625           0.503148
# 4     11.223015      1.530934      2.887973   0.120332           0.517968

# %%
# 5th hyperparameter settings
sphere_pop500_mutrate0_5_mutrange0_5 = glob.glob('csv_results/10_iterations_3_genes_grow_mutate_added/sphere_experiment_pop500_mutrate0.5_mutrange0.5/*.csv')
csv_list = []

for csv_file in sphere_pop500_mutrate0_5_mutrange0_5:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop500_mutrate0_5_mutrange0_5_df = pd.concat(csv_list, ignore_index=True)

sphere_pop500_mutrate0_5_mutrange0_5_df.head(5)
# Out:
#    max_distance  min_distance  avg_distance  avg_speed  path_straightness
# 0      9.272546      1.049703      2.677598   0.111567           0.453245
# 1     10.541107      1.561497      2.713445   0.113060           0.487895
# 2      7.546697      1.409286      2.658386   0.110766           0.481584
# 3      7.625290      1.573192      2.674878   0.111453           0.490125
# 4      7.434466      1.018547      2.650337   0.110431           0.510718

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))

# define your dataframes
dataframes = [
    sphere_pop100_mutrate0_1_mutrange0_5_df,
    sphere_pop100_mutrate0_2_mutrange0_5_df,
    sphere_pop200_mutrate0_1_mutrange0_5_df,
    sphere_pop200_mutrate0_5_mutrange0_5_df,
    sphere_pop500_mutrate0_5_mutrange0_5_df
]

colors = ['blue', 'red', 'green', 'purple', 'orange']
labels = ['100_0.1_0.5', '100_0.2_0.5', '200_0.1_0.5', '200_0.5_0.5', '500_0.5_0.5']

for dataframe, color, label in zip(dataframes, colors, labels):
    for (i, j), ax in np.ndenumerate(axs):
        metric = ['max_distance', 'avg_distance', 'avg_speed', 'path_straightness'][i*2 + j]

        # plot data
        ax.plot(dataframe.index, dataframe[metric], color=color, label=label)

        # calculate best fit line
        coef = np.polyfit(dataframe.index, dataframe[metric], 1)
        poly1d_fn = np.poly1d(coef)

        # plot best fit line
        ax.plot(dataframe.index, poly1d_fn(dataframe.index), color=color, linestyle='--')

# add legends
for ax in axs.flat:
    ax.legend()

# Set titles
axs[0, 0].set_title('Max Distance (box, 10i, 3g)')
axs[0, 1].set_title('Avg Distance (box, 10i, 3g)')
axs[1, 0].set_title('Avg Speed (box, 10i, 3g)')
axs[1, 1].set_title('Path Straightness (box, 10i, 3g)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Best Creature
# python .\wk4_end\realtime_from_csv.py .\csv_results\10_iterations_3_genes_grow_mutate_added\sphere_experiment_pop200_mutrate0.1_mutrange0.5_fittest_creature\generation_9_fittest_creature.csv
