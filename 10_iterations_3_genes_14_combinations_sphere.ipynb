# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob
import numpy as np

# %%
# 1st hyperparameter settings
sphere_pop100_mutrate0_4_mutrange0_1 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop100_mutrate0.4_mutrange0.1/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop100_mutrate0_4_mutrange0_1:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop100_mutrate0_4_mutrange0_1_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop100_mutrate0_4_mutrange0_1_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop100_mutrate0_4_mutrange0_1_df[column_name].idxmax()
max_value_row = sphere_pop100_mutrate0_4_mutrange0_1_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         11.180818
# min_distance          1.703999
# avg_distance          2.847155
# avg_speed             0.059316
# path_straightness     0.478831
# Name: 0, dtype: float64---------
#
# The index of the row of the fittest creature: 0

# %%
# 2nd hyperparameter settings
sphere_pop100_mutrate0_8_mutrange0_1 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop100_mutrate0.8_mutrange0.1/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop100_mutrate0_8_mutrange0_1:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop100_mutrate0_8_mutrange0_1_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop100_mutrate0_8_mutrange0_1_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop100_mutrate0_8_mutrange0_1_df[column_name].idxmax()
max_value_row = sphere_pop100_mutrate0_8_mutrange0_1_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         14.815821
# min_distance          1.479628
# avg_distance          2.655908
# avg_speed             0.055331
# path_straightness     0.455676
# Name: 0, dtype: float64---------
#
# The index of the row of the fittest creature: 0

# %%
# 3rd hyperparameter settings
sphere_pop100_mutrate0_8_mutrange0_8 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop100_mutrate0.8_mutrange0.8/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop100_mutrate0_8_mutrange0_8:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop100_mutrate0_8_mutrange0_8_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop100_mutrate0_8_mutrange0_8_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop100_mutrate0_8_mutrange0_8_df[column_name].idxmax()
max_value_row = sphere_pop100_mutrate0_8_mutrange0_8_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         8.858669
# min_distance         1.459325
# avg_distance         2.719777
# avg_speed            0.056662
# path_straightness    0.433271
# Name: 1, dtype: float64---------
#
# The index of the row of the fittest creature: 1

# %%
# 4th hyperparameter settings
sphere_pop300_mutrate0_1_mutrange0_1 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop300_mutrate0.1_mutrange0.1/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop300_mutrate0_1_mutrange0_1:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop300_mutrate0_1_mutrange0_1_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop300_mutrate0_1_mutrange0_1_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop300_mutrate0_1_mutrange0_1_df[column_name].idxmax()
max_value_row = sphere_pop300_mutrate0_1_mutrange0_1_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         17.165432
# min_distance          1.579985
# avg_distance          3.732260
# avg_speed             0.077755
# path_straightness     0.549891
# Name: 5, dtype: float64---------
#
# The index of the row of the fittest creature: 5

# %%
# 5th hyperparameter settings
sphere_pop300_mutrate0_1_mutrange0_4 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop300_mutrate0.1_mutrange0.4/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop300_mutrate0_1_mutrange0_4:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop300_mutrate0_1_mutrange0_4_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop300_mutrate0_1_mutrange0_4_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop300_mutrate0_1_mutrange0_4_df[column_name].idxmax()
max_value_row = sphere_pop300_mutrate0_1_mutrange0_4_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         26.446344
# min_distance          1.483485
# avg_distance          3.198852
# avg_speed             0.066643
# path_straightness     0.484306
# Name: 3, dtype: float64---------
#
# The index of the row of the fittest creature: 3

# %%
# 6th hyperparameter settings
sphere_pop300_mutrate0_1_mutrange0_8 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop300_mutrate0.1_mutrange0.8/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop300_mutrate0_1_mutrange0_8:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop300_mutrate0_1_mutrange0_8_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop300_mutrate0_1_mutrange0_8_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop300_mutrate0_1_mutrange0_8_df[column_name].idxmax()
max_value_row = sphere_pop300_mutrate0_1_mutrange0_8_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         10.229175
# min_distance          1.629031
# avg_distance          4.707696
# avg_speed             0.098077
# path_straightness     0.618654
# Name: 9, dtype: float64---------
#
# The index of the row of the fittest creature: 9

# %%
# 7th hyperparameter settings
sphere_pop300_mutrate0_4_mutrange0_1 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop300_mutrate0.4_mutrange0.1/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop300_mutrate0_4_mutrange0_1:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop300_mutrate0_4_mutrange0_1_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop300_mutrate0_4_mutrange0_1_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop300_mutrate0_4_mutrange0_1_df[column_name].idxmax()
max_value_row = sphere_pop300_mutrate0_4_mutrange0_1_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         12.137152
# min_distance          1.425444
# avg_distance          3.161392
# avg_speed             0.065862
# path_straightness     0.564108
# Name: 7, dtype: float64---------
#
# The index of the row of the fittest creature: 7

# %%
# 8th hyperparameter settings
sphere_pop300_mutrate0_4_mutrange0_4 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop300_mutrate0.4_mutrange0.4/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop300_mutrate0_4_mutrange0_4:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop300_mutrate0_4_mutrange0_4_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop300_mutrate0_4_mutrange0_4_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop300_mutrate0_4_mutrange0_4_df[column_name].idxmax()
max_value_row = sphere_pop300_mutrate0_4_mutrange0_4_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         8.577890
# min_distance         1.081514
# avg_distance         2.633576
# avg_speed            0.054866
# path_straightness    0.556836
# Name: 9, dtype: float64---------
#
# The index of the row of the fittest creature: 9

# %%
# 9th hyperparameter settings
sphere_pop300_mutrate0_8_mutrange0_1 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop300_mutrate0.8_mutrange0.1/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop300_mutrate0_8_mutrange0_1:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop300_mutrate0_8_mutrange0_1_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop300_mutrate0_8_mutrange0_1_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop300_mutrate0_8_mutrange0_1_df[column_name].idxmax()
max_value_row = sphere_pop300_mutrate0_8_mutrange0_1_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         10.680376
# min_distance          1.514772
# avg_distance          2.330786
# avg_speed             0.048558
# path_straightness     0.528062
# Name: 5, dtype: float64---------
#
# The index of the row of the fittest creature: 5

# %%
# 10th hyperparameter settings
sphere_pop300_mutrate0_8_mutrange0_8 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop300_mutrate0.8_mutrange0.8/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop300_mutrate0_8_mutrange0_8:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop300_mutrate0_8_mutrange0_8_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop300_mutrate0_8_mutrange0_8_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop300_mutrate0_8_mutrange0_8_df[column_name].idxmax()
max_value_row = sphere_pop300_mutrate0_8_mutrange0_8_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         8.684520
# min_distance         1.203348
# avg_distance         2.474173
# avg_speed            0.051545
# path_straightness    0.524087
# Name: 5, dtype: float64---------
#
# The index of the row of the fittest creature: 5

# %%
# 11th hyperparameter settings
sphere_pop600_mutrate0_1_mutrange0_1 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop600_mutrate0.1_mutrange0.1/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop600_mutrate0_1_mutrange0_1:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop600_mutrate0_1_mutrange0_1_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop600_mutrate0_1_mutrange0_1_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop600_mutrate0_1_mutrange0_1_df[column_name].idxmax()
max_value_row = sphere_pop600_mutrate0_1_mutrange0_1_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         57.685037
# min_distance          1.474534
# avg_distance          3.474251
# avg_speed             0.072380
# path_straightness     0.556795
# Name: 9, dtype: float64---------
#
# The index of the row of the fittest creature: 9

# %%
# 12th hyperparameter settings
sphere_pop600_mutrate0_1_mutrange0_4 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop600_mutrate0.1_mutrange0.4/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop600_mutrate0_1_mutrange0_4:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop600_mutrate0_1_mutrange0_4_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop600_mutrate0_1_mutrange0_4_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop600_mutrate0_1_mutrange0_4_df[column_name].idxmax()
max_value_row = sphere_pop600_mutrate0_1_mutrange0_4_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         10.408037
# min_distance          1.527184
# avg_distance          3.733047
# avg_speed             0.077772
# path_straightness     0.570626
# Name: 9, dtype: float64---------
#
# The index of the row of the fittest creature: 9

# %%
# 13th hyperparameter settings
sphere_pop600_mutrate0_1_mutrange0_8 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop600_mutrate0.1_mutrange0.8/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop600_mutrate0_1_mutrange0_8:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop600_mutrate0_1_mutrange0_8_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop600_mutrate0_1_mutrange0_8_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop600_mutrate0_1_mutrange0_8_df[column_name].idxmax()
max_value_row = sphere_pop600_mutrate0_1_mutrange0_8_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         10.500296
# min_distance          1.441770
# avg_distance          3.646098
# avg_speed             0.075960
# path_straightness     0.577670
# Name: 8, dtype: float64---------
#
# The index of the row of the fittest creature: 8

# %%
# 14th hyperparameter settings
sphere_pop600_mutrate0_4_mutrange0_4 = glob.glob('csv_results/10_iterations_3_genes_22_combinations/sphere_experiment_pop600_mutrate0.4_mutrange0.4/fitness_data/*.csv')
csv_list = []

for csv_file in sphere_pop600_mutrate0_4_mutrange0_4:
    df = pd.read_csv(csv_file)
    csv_list.append(df)
    
sphere_pop600_mutrate0_4_mutrange0_4_df = pd.concat(csv_list, ignore_index=True)

# sphere_pop600_mutrate0_4_mutrange0_4_df.head(5)

column_name = 'max_distance'
max_value_index = sphere_pop600_mutrate0_4_mutrange0_4_df[column_name].idxmax()
max_value_row = sphere_pop600_mutrate0_4_mutrange0_4_df.loc[max_value_index]
print(f"The data from the fittest creature: \n{max_value_row}---------\n\nThe index of the row of the fittest creature: {max_value_index}")
# Out:
# The data from the fittest creature:
# max_distance         9.730635
# min_distance         1.503288
# avg_distance         3.014964
# avg_speed            0.062812
# path_straightness    0.552226
# Name: 7, dtype: float64---------
#
# The index of the row of the fittest creature: 7

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))

# define your dataframes
dataframes = [
    sphere_pop100_mutrate0_4_mutrange0_1_df,
    sphere_pop100_mutrate0_8_mutrange0_1_df,
    sphere_pop100_mutrate0_8_mutrange0_8_df,
    
    sphere_pop300_mutrate0_1_mutrange0_1_df,
    sphere_pop300_mutrate0_1_mutrange0_4_df,
    
]

colors = ['blue', 'red', 'green', 'purple', 'orange']
labels = [
    '100_0.4_0.1', '100_0.8_0.1', '100_0.8_0.8',
    '300_0.1_0.1', '300_0.1_0.4', '300_0.1_0.8',
    '300_0.4_0.1', '300_0.4_0.4', '300_0.8_0.1',
    '300_0.8_0.8', '600_0.1_0.1', '600_0.1_0.4',
    '600_0.1_0.8', '600_0.4_0.4',
         ]

for dataframe, color, label in zip(dataframes, colors, labels):
    for (i, j), ax in np.ndenumerate(axs):
        metric = ['max_distance', 'avg_distance', 'avg_speed', 'path_straightness'][i*2 + j]

        # plot data
        ax.plot(dataframe.index, dataframe[metric], color=color, label=label)

        # calculate best fit line
        coef = np.polyfit(dataframe.index, dataframe[metric], 1)
        poly1d_fn = np.poly1d(coef)

        # plot best fit line
        ax.plot(dataframe.index, poly1d_fn(dataframe.index), color=color, linestyle='--')

# add legends
for ax in axs.flat:
    ax.legend()

# Set titles
axs[0, 0].set_title('Max Distance (box, 10i, 3g)')
axs[0, 1].set_title('Avg Distance (box, 10i, 3g)')
axs[1, 0].set_title('Avg Speed (box, 10i, 3g)')
axs[1, 1].set_title('Path Straightness (box, 10i, 3g)')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))

# define your dataframes
dataframes = [

    sphere_pop300_mutrate0_1_mutrange0_8_df,
    sphere_pop300_mutrate0_4_mutrange0_1_df,
    sphere_pop300_mutrate0_4_mutrange0_4_df,
    sphere_pop300_mutrate0_8_mutrange0_1_df,
    sphere_pop300_mutrate0_8_mutrange0_8_df,
    
]

colors = ['blue', 'red', 'green', 'purple', 'orange']
labels = [
    '300_0.1_0.8',
    '300_0.4_0.1', '300_0.4_0.4', '300_0.8_0.1',
    '300_0.8_0.8'
         ]

# change the loop to iterate over all 14 dataframes
for dataframe, color, label in zip(dataframes, colors, labels):
    # plot the data for each dataframe
    for (i, j), ax in np.ndenumerate(axs):
        metric = ['max_distance', 'avg_distance', 'avg_speed', 'path_straightness'][i*2 + j]

        ax.plot(dataframe.index, dataframe[metric], color=color, label=label)

# add legends
for ax in axs.flat:
    ax.legend()

# Set titles
axs[0, 0].set_title('Max Distance (box, 10i, 3g)')
axs[0, 1].set_title('Avg Distance (box, 10i, 3g)')
axs[1, 0].set_title('Avg Speed (box, 10i, 3g)')
axs[1, 1].set_title('Path Straightness (box, 10i, 3g)')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))

# define your dataframes
dataframes = [
    
    sphere_pop600_mutrate0_1_mutrange0_1_df,
    sphere_pop600_mutrate0_1_mutrange0_4_df,
    sphere_pop600_mutrate0_1_mutrange0_8_df,
    sphere_pop600_mutrate0_4_mutrange0_4_df
]


colors = ['blue', 'red', 'green', 'purple', 'orange']
labels = [
    '600_0.1_0.1', '600_0.1_0.4',
    '600_0.1_0.8', '600_0.4_0.4',
         ]

# change the loop to iterate over all 14 dataframes
for dataframe, color, label in zip(dataframes, colors, labels):
    # plot the data for each dataframe
    for (i, j), ax in np.ndenumerate(axs):
        metric = ['max_distance', 'avg_distance', 'avg_speed', 'path_straightness'][i*2 + j]

        ax.plot(dataframe.index, dataframe[metric], color=color, label=label)

# add legends
for ax in axs.flat:
    ax.legend()

# Set titles
axs[0, 0].set_title('Max Distance (box, 10i, 3g)')
axs[0, 1].set_title('Avg Distance (box, 10i, 3g)')
axs[1, 0].set_title('Avg Speed (box, 10i, 3g)')
axs[1, 1].set_title('Path Straightness (box, 10i, 3g)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Best Creature
#
# python .\wk4_end\realtime_from_csv.py .\csv_results\10_iterations_3_genes_22_combinations\sphere_experiment_pop600_mutrate0.1_mutrange0.1\fittest_creature\generation_9_fittest_creature.csv
